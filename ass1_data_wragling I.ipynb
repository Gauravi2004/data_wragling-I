# %%
import numpy as np

# %%
# !pip install pandas

# %%
import pandas as pd
# Out:
# C:\Users\darsh\AppData\Local\Temp\ipykernel_25344\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("archive 1/Latest Covid-19 India Status.csv")
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
df.tail()
# Out:
#         State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 31      Telengana       844432       8      840313    4111          0.00
# 32        Tripura       108493       1      107550     942          0.00
# 33  Uttar Pradesh      2145431      57     2121662   23712          0.00
# 34    Uttarakhand       452571       0      444803    7768          0.00
# 35    West Bengal      2126282     135     2104592   21555          0.01
#
#     Discharge Ratio  Death Ratio  Population
# 31            99.51         0.49    69599762
# 32            99.13         0.87     1646050
# 33            98.89         1.11     1158040
# 34            98.28         1.72    85002417
# 35            98.98         1.01    32199722

# %%
df.describe()
# Out:
#         Total Cases       Active    Discharged         Deaths  Active Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.249975e+06    50.333333  1.235146e+06   14778.527778      0.005000
# std    1.846038e+06   207.118048  1.820328e+06   27221.140636      0.026673
# min    1.076600e+04     0.000000  1.063700e+04       4.000000      0.000000
# 25%    1.065430e+05     0.000000  1.055395e+05    1124.250000      0.000000
# 50%    6.140910e+05     1.500000  6.076750e+05    6551.000000      0.000000
# 75%    1.331951e+06     9.000000  1.322329e+06   14325.750000      0.000000
# max    8.171048e+06  1233.000000  8.022276e+06  148558.000000      0.160000
#
#        Discharge Ratio  Death Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.897222     1.097778  3.971861e+07
# std           0.506854     0.494791  5.050913e+07
# min          97.410000     0.030000  6.600100e+04
# ...

# %%
df.isnull().head()
# Out:
#    State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0      False        False   False       False   False         False
# 1      False        False   False       False   False         False
# 2      False        False   False       False   False         False
# 3      False        False   False       False   False         False
# 4      False        False   False       False   False         False
#
#    Discharge Ratio  Death Ratio  Population
# 0            False        False       False
# 1            False        False       False
# 2            False        False       False
# 3            False        False       False
# 4            False        False       False

# %%
df.shape
# Out:
# (36, 9)

# %%
df.dtypes
# Out:
# State/UTs           object
# Total Cases          int64
# Active               int64
# Discharged           int64
# Deaths               int64
# Active Ratio       float64
# Discharge Ratio    float64
# Death Ratio        float64
# Population           int64
# dtype: object

# %%
df.Active.dtype
# Out:
# dtype('int64')

# %%
### 6. Turn categorical variables into quantitative variables in Python

# %%
cd=pd.read_csv('archive 1/statewise_tested_numbers_data.csv')
cd
# Out:
#       Updated On                        State  Total Tested  \
# 0     17/04/2020  Andaman and Nicobar Islands        1403.0
# 1     24/04/2020  Andaman and Nicobar Islands        2679.0
# 2     27/04/2020  Andaman and Nicobar Islands        2848.0
# 3     01/05/2020  Andaman and Nicobar Islands        3754.0
# 4     16/05/2020  Andaman and Nicobar Islands        6677.0
# ...          ...                          ...           ...
# 3280  15/07/2020                  West Bengal      649928.0
# 3281  16/07/2020                  West Bengal      663108.0
# 3282  17/07/2020                  West Bengal      676348.0
# 3283  18/07/2020                  West Bengal      689813.0
# 3284  19/07/2020                  West Bengal           NaN
#
#      Tag (Total Tested)  Positive Negative  Unconfirmed  \
# 0          Samples Sent      12.0     1210        181.0
# 1          Samples Sent      27.0      NaN        246.0
# 2          Samples Sent      33.0      NaN        106.0
# ...

# %%
cd['State']
# Out:
# 0       Andaman and Nicobar Islands
# 1       Andaman and Nicobar Islands
# 2       Andaman and Nicobar Islands
# 3       Andaman and Nicobar Islands
# 4       Andaman and Nicobar Islands
#                    ...
# 3280                    West Bengal
# 3281                    West Bengal
# 3282                    West Bengal
# 3283                    West Bengal
# 3284                    West Bengal
# Name: State, Length: 3285, dtype: object

# %%
cd['State'] = cd['State'].astype('category').cat.codes
print(cd)
# Out:
#       Updated On  State  Total Tested Tag (Total Tested)  Positive Negative  \
# 0     17/04/2020      0        1403.0       Samples Sent      12.0     1210
# 1     24/04/2020      0        2679.0       Samples Sent      27.0      NaN
# 2     27/04/2020      0        2848.0       Samples Sent      33.0      NaN
# 3     01/05/2020      0        3754.0       Samples Sent      33.0      NaN
# 4     16/05/2020      0        6677.0       Samples Sent      33.0      NaN
# ...          ...    ...           ...                ...       ...      ...
# 3280  15/07/2020     34      649928.0             Tested   34427.0      NaN
# 3281  16/07/2020     34      663108.0             Tested   36117.0      NaN
# 3282  17/07/2020     34      676348.0             Tested   38011.0      NaN
# 3283  18/07/2020     34      689813.0             Tested   40209.0      NaN
# 3284  19/07/2020     34           NaN                NaN       NaN      NaN
#
#       Unconfirmed  Cumulative People In Quarantine  \
# ...

# %%
with pd.option_context('display.max_rows', None):
    print(cd)
# Out:
#       Updated On  State  Total Tested Tag (Total Tested)  Positive Negative  \
# 0     17/04/2020      0        1403.0       Samples Sent      12.0     1210
# 1     24/04/2020      0        2679.0       Samples Sent      27.0      NaN
# 2     27/04/2020      0        2848.0       Samples Sent      33.0      NaN
# 3     01/05/2020      0        3754.0       Samples Sent      33.0      NaN
# 4     16/05/2020      0        6677.0       Samples Sent      33.0      NaN
# 5     19/05/2020      0        6965.0       Samples Sent      33.0      NaN
# 6     20/05/2020      0        7082.0       Samples Sent      33.0      NaN
# 7     21/05/2020      0        7167.0       Samples Sent      33.0      NaN
# 8     22/05/2020      0        7263.0       Samples Sent      33.0      NaN
# 9     23/05/2020      0        7327.0       Samples Sent      33.0      NaN
# 10    24/05/2020      0        7327.0       Samples Sent      33.0      NaN
# ...

# %%
cd.shape
# Out:
# (3285, 28)
